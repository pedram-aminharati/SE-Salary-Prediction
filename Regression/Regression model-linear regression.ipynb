# %%
import pandas as pd
import re
import numpy as np
from scipy.stats import zscore

# %%
data_path = "SoftwareEngineer_cleaned.csv"
df = pd.read_csv(data_path)
print(df.shape)
df.head()
# Out:
# (34012, 12)
#                title level    company  yearsofexperience  \
# 0  Software Engineer  SE 2       eBay                5.0
# 1  Software Engineer    60  Microsoft                5.0
# 2  Software Engineer    63  Microsoft                8.5
# 3  Software Engineer    62  Microsoft                4.0
# 4  Software Engineer    59  Microsoft                3.0
#
#    totalyearlycompensation gender  Doctorate_Degree  Masters_Degree  \
# 0                   100000    NaN                 0               0
# 1                   157000    NaN                 0               0
# 2                   208000    NaN                 0               0
# 3                   156000    NaN                 0               0
# 4                   120000    NaN                 0               0
#
#    Bachelors_Degree  tag state           city
# 0                 0  NaN    CA  San Francisco
# 1                 0  NaN    CA  Mountain View
# 2                 0  NaN    WA        Seattle
# 3                 0  NaN    WA        Seattle
# 4                 0  NaN    WA        Redmond

# %% [markdown]
# # Normalization

# %% [markdown]
# The goal of normalization is to transform features to be on a similar scale. This improves the performance and training stability of the model.

# %% [markdown]
# Perform z-score normalization method. This process is necessary so that the machine learning models treat all variables equally, and a variable is not considered more important because it has a higher range of values

# %%
df['Totalyearlycopensation_Zscore_Normalize'] = zscore(df['totalyearlycompensation'])

display(df)
# Out:
#                    title     level     company  yearsofexperience  \
# 0      Software Engineer      SE 2        eBay                5.0
# 1      Software Engineer        60   Microsoft                5.0
# 2      Software Engineer        63   Microsoft                8.5
# 3      Software Engineer        62   Microsoft                4.0
# 4      Software Engineer        59   Microsoft                3.0
# ...                  ...       ...         ...                ...
# 34007  Software Engineer        T4      Google               10.0
# 34008  Software Engineer        62   Microsoft                2.0
# 34009  Software Engineer        63        MSFT               14.0
# 34010  Software Engineer  Lead MTS  Salesforce                8.0
# 34011  Software Engineer      ict3       apple                0.0
#
#        totalyearlycompensation gender  Doctorate_Degree  Masters_Degree  \
# 0                       100000    NaN                 0               0
# 1                       157000    NaN                 0               0
# 2                       208000    NaN                 0               0
# 3                       156000    NaN                 0               0
# 4                       120000    NaN                 0               0
# ...                        ...    ...               ...             ...
# 34007                   327000    NaN                 0               0
# 34008                   237000    NaN                 0               0
# 34009                   220000    NaN                 0               0
# 34010                   280000    NaN                 0               0
# 34011                   200000   Male                 0               0
#
#        Bachelors_Degree                             tag state           city  \
# 0                     0                             NaN    CA  San Francisco
# 1                     0                             NaN    CA  Mountain View
# 2                     0                             NaN    WA        Seattle
# 3                     0                             NaN    WA        Seattle
# 4                     0                             NaN    WA        Redmond
# ...                 ...                             ...   ...            ...
# 34007                 0  Distributed Systems (Back-End)    WA        Seattle
# 34008                 0                      Full Stack    WA        Redmond
# 34009                 0                      Full Stack    WA        Seattle
# 34010                 0                             iOS    CA  San Francisco
# 34011                 0                         ML / AI    CA      Sunnyvale
#
#        Totalyearlycopensation_Zscore_Normalize
# 0                                    -1.097077
# 1                                    -0.595409
# 2                                    -0.146549
# 3                                    -0.604211
# 4                                    -0.921053
# ...                                        ...
# 34007                                 0.900791
# 34008                                 0.108685
# 34009                                -0.040935
# 34010                                 0.487135
# 34011                                -0.216959
#
# [34012 rows x 13 columns]
